# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
num_puntos = 100
conjunto_puntos = []
for i in range(num_puntos):
    x1= np.random.normal(0.0, 0.55)
    y1= x1 * 0.1 + 0.3 + np.random.normal(0.0, 0.03)
    conjunto_puntos.append([x1, y1])
    
    
x_data = [v[0] for v in conjunto_puntos]
y_data = [v[1] for v in conjunto_puntos]

plt.plot(x_data, y_data, 'ro', label='Original data')
plt.legend()
plt.show()
'''
print(x_data)
print("============================")
print(y_data)
print("================================")
print(conjunto_puntos)'''
# Out:
# '\nprint(x_data)\nprint("============================")\nprint(y_data)\nprint("================================")\nprint(conjunto_puntos)'

# %%
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b
loss = tf.reduce_mean(tf.square(y - y_data))
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)
for step in range(20):
    print(step, sess.run(W), sess.run(b))
    sess.run(train)
# Out:
# 0 [-0.40121317] [0.]
# 1 [-0.2628718] [0.27069166]
# 2 [-0.1520856] [0.27857566]
# 3 [-0.0752706] [0.28488928]
# 4 [-0.02196169] [0.2892669]
# 5 [0.015034] [0.29230496]
# 6 [0.04070851] [0.29441333]
# 7 [0.05852629] [0.2958765]
# 8 [0.07089159] [0.29689193]
# 9 [0.07947294] [0.2975966]
# 10 [0.08542829] [0.29808566]
# 11 [0.08956122] [0.29842505]
# 12 [0.09242943] [0.29866058]
# 13 [0.09441992] [0.29882404]
# 14 [0.09580129] [0.2989375]
# 15 [0.09675995] [0.2990162]
# 16 [0.09742525] [0.29907084]
# 17 [0.09788696] [0.29910874]
# 18 [0.09820738] [0.29913506]
# 19 [0.09842974] [0.29915333]

# %%
sess.run(init)
for step in range(50):
    sess.run(train)
    print(step, sess.run(W), sess.run(b))
    y_pred_value=sess.run(y)
    plt.plot(x_data, y_data,'go', x_data, y_pred_value, 'ro')
    w_value=sess.run(W)
    b_value=sess.run(b)
    text="$ {} x + {}$".format(w_value, b_value)
    plt.text(-1, .4, text)
    plt.show()
# Out:
# 0 [0.21366882] [0.3100903]
# 1 [0.17864245] [0.3057334]
# 2 [0.15425023] [0.30373728]
# 3 [0.13732275] [0.30234718]
# 4 [0.1255753] [0.30138248]
# 5 [0.11742272] [0.300713]
# 6 [0.11176494] [0.30024838]
# 7 [0.10783851] [0.29992595]
# 8 [0.10511362] [0.2997022]
# 9 [0.10322258] [0.2995469]
# 10 [0.10191023] [0.29943913]
# 11 [0.10099947] [0.29936436]
# 12 [0.10036742] [0.29931244]
# 13 [0.09992878] [0.2992764]
# 14 [0.09962437] [0.29925144]
# 15 [0.09941312] [0.2992341]
# 16 [0.09926651] [0.29922205]
# 17 [0.09916477] [0.29921368]
# 18 [0.09909416] [0.2992079]
# 19 [0.09904516] [0.29920387]
# 20 [0.09901115] [0.29920107]
# 21 [0.09898755] [0.29919913]
# 22 [0.09897117] [0.2991978]
# 23 [0.0989598] [0.29919687]
# 24 [0.09895192] [0.2991962]
# 25 [0.09894644] [0.29919577]
# 26 [0.09894264] [0.29919544]
# 27 [0.09894001] [0.29919523]
# 28 [0.09893817] [0.29919508]
# 29 [0.09893691] [0.29919496]
# 30 [0.09893603] [0.2991949]
# 31 [0.09893542] [0.29919484]
# 32 [0.09893499] [0.2991948]
# 33 [0.0989347] [0.29919478]
# 34 [0.09893449] [0.29919478]
# 35 [0.09893435] [0.29919475]
# 36 [0.09893426] [0.29919475]
# 37 [0.09893419] [0.29919475]
# 38 [0.09893414] [0.29919475]
# 39 [0.09893411] [0.29919475]
# 40 [0.09893408] [0.29919475]
# 41 [0.09893407] [0.29919475]
# 42 [0.09893405] [0.29919475]
# 43 [0.09893405] [0.29919475]
# 44 [0.09893404] [0.29919475]
# 45 [0.09893404] [0.29919475]
# 46 [0.09893404] [0.29919475]
# 47 [0.09893404] [0.29919475]
# 48 [0.09893404] [0.29919475]
# 49 [0.09893404] [0.29919475]
